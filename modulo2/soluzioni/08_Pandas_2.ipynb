# %% [markdown]
# # Pandas - Parte 2
#
# Nelle lezioni precedenti abbiamo visto le funzionalità di base di Pandas. Oggi vediamo alcune funzionalità più avanzate, fra cui quelle che ci permettono di combinare i contenuti di più DataFrame in uno.
#
# Prima di partire, come al solito, importiamo pandas:

# %%
import pandas as pd

# %% [markdown]
# ## Chained indexing
#
# Ricominciamo da dove eravamo rimasti, con il nostro DataFrame di film dello studio Ghibli, con la colonna "won oscar" che conteneva un errore:

# %%
ghibli_movies = pd.DataFrame({
    "title" : ["Princess Mononoke", "Grave of the Fireflies", "Porco Rosso", 
               "Tales from Earthsea", "Spirited Away"],
    "director" : ["Hayao Miyazaki", "Isao Takahata", "Hayao Miyazaki", "Gorō Miyazaki", "Hayao Miyazaki"],
    "saddest movie ever?" : [False, True, False, False, False],
    "year": [1997, 1988, 1992, 2006, 2001],
    "won oscar": [False, False, False, False, False]
    },
    index = [1997, 1988, 1992, 2006, 2001]
)

ghibli_movies
# Out:
#                        title        director  saddest movie ever?  year  \
# 1997       Princess Mononoke  Hayao Miyazaki                False  1997
# 1988  Grave of the Fireflies   Isao Takahata                 True  1988
# 1992             Porco Rosso  Hayao Miyazaki                False  1992
# 2006     Tales from Earthsea   Gorō Miyazaki                False  2006
# 2001           Spirited Away  Hayao Miyazaki                False  2001
#
#       won oscar
# 1997      False
# 1988      False
# 1992      False
# 2006      False
# 2001      False

# %% [markdown]
# Proviamo ad assegnare la colonna "won oscar" con il valore corretto:

# %%
ghibli_movies[ghibli_movies["title"]=="Spirited Away"]["won oscar"] = True

ghibli_movies
# Out:
# /tmp/ipykernel_5583/2481038265.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ghibli_movies[ghibli_movies["title"]=="Spirited Away"]["won oscar"] = True
#                        title        director  saddest movie ever?  year  \
# 1997       Princess Mononoke  Hayao Miyazaki                False  1997
# 1988  Grave of the Fireflies   Isao Takahata                 True  1988
# 1992             Porco Rosso  Hayao Miyazaki                False  1992
# 2006     Tales from Earthsea   Gorō Miyazaki                False  2006
# 2001           Spirited Away  Hayao Miyazaki                False  2001
#
#       won oscar
# 1997      False
# 1988      False
# 1992      False
# 2006      False
# 2001      False

# %%
spirited_away = ghibli_movies[ghibli_movies["title"]=="Spirited Away"]

spirited_away["won oscar"] = True

print("===SPIRITED AWAY===")
print(spirited_away)
print("===ALL MOVIES===")
print(ghibli_movies)
# Out:
# ===SPIRITED AWAY===
#               title        director  saddest movie ever?  year  won oscar
# 2001  Spirited Away  Hayao Miyazaki                False  2001       True
# ===ALL MOVIES===
#                        title        director  saddest movie ever?  year  \
# 1997       Princess Mononoke  Hayao Miyazaki                False  1997
# 1988  Grave of the Fireflies   Isao Takahata                 True  1988
# 1992             Porco Rosso  Hayao Miyazaki                False  1992
# 2006     Tales from Earthsea   Gorō Miyazaki                False  2006
# 2001           Spirited Away  Hayao Miyazaki                False  2001
#
#       won oscar
# 1997      False
# 1988      False
# 1992      False
# 2006      False
# 2001      False

# %% [markdown]
# Cerchiamo di capire questo errore: abbiamo fatto quello che si chiama *chained indexing*. Infatti se notate abbiamo usato due metodi di indicizzazione per il nostro DataFrame: prima chiediamo le righe dove il titolo è == a "Spirited Away", poi indicizziamo la colonna "won oscar". Questo crea **una copia** del nostro DataFrame, e infatti non abbiamo modificato l'originale!
#
# Per risolvere questo problema, possiamo usare `.loc` quando vogliamo riassegnare un valore del DataFrame

# %%
ghibli_movies.loc[2001, "won oscar"] = True

ghibli_movies
# Out:
#                        title        director  saddest movie ever?  year  \
# 1997       Princess Mononoke  Hayao Miyazaki                False  1997
# 1988  Grave of the Fireflies   Isao Takahata                 True  1988
# 1992             Porco Rosso  Hayao Miyazaki                False  1992
# 2006     Tales from Earthsea   Gorō Miyazaki                False  2006
# 2001           Spirited Away  Hayao Miyazaki                False  2001
#
#       won oscar
# 1997      False
# 1988      False
# 1992      False
# 2006      False
# 2001       True

# %% [markdown]
# Oppure possiamo usare `.at`

# %%
ghibli_movies["won oscar"] = False
ghibli_movies.at[2001, "won oscar"] = True

ghibli_movies
# Out:
#                        title        director  saddest movie ever?  year  \
# 1997       Princess Mononoke  Hayao Miyazaki                False  1997
# 1988  Grave of the Fireflies   Isao Takahata                 True  1988
# 1992             Porco Rosso  Hayao Miyazaki                False  1992
# 2006     Tales from Earthsea   Gorō Miyazaki                False  2006
# 2001           Spirited Away  Hayao Miyazaki                False  2001
#
#       won oscar
# 1997      False
# 1988      False
# 1992      False
# 2006      False
# 2001       True

# %% [markdown]
# ## Sorting
#
# Una delle operazioni che non abbiamo ancora discusso è quella di **ordinamento** (*sorting*) dei DataFrame. Possiamo infatti riordinare gli assi del nostro DataFrame usando il metodo `.sort_values`.

# %%
ghibli_movies = pd.DataFrame({
    "title" : ["Princess Mononoke", "Grave of the Fireflies", "Porco Rosso", "Tales from Earthsea", "Spirited Away"],
    "director" : ["Hayao Miyazaki", "Isao Takahata", "Hayao Miyazaki", "Gorō Miyazaki", "Hayao Miyazaki"],
    "saddest movie ever?" : [False, True, False, False, False],
    "year": [1997, 1988, 1992, 2006, 2001],
    "won oscar": [False, False, False, False, True]
    }
)
ghibli_movies
# Out:
#                     title        director  saddest movie ever?  year  \
# 0       Princess Mononoke  Hayao Miyazaki                False  1997
# 1  Grave of the Fireflies   Isao Takahata                 True  1988
# 2             Porco Rosso  Hayao Miyazaki                False  1992
# 3     Tales from Earthsea   Gorō Miyazaki                False  2006
# 4           Spirited Away  Hayao Miyazaki                False  2001
#
#    won oscar
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True

# %%
ghibli_movies.sort_values("year")
# Out:
#                     title        director  saddest movie ever?  year  \
# 1  Grave of the Fireflies   Isao Takahata                 True  1988
# 2             Porco Rosso  Hayao Miyazaki                False  1992
# 0       Princess Mononoke  Hayao Miyazaki                False  1997
# 4           Spirited Away  Hayao Miyazaki                False  2001
# 3     Tales from Earthsea   Gorō Miyazaki                False  2006
#
#    won oscar
# 1      False
# 2      False
# 0      False
# 4       True
# 3      False

# %% [markdown]
# Attenzione però: la variabile originale `ghibli_movies` non è stata modificata

# %%
ghibli_movies
# Out:
#                     title        director  saddest movie ever?  year  \
# 0       Princess Mononoke  Hayao Miyazaki                False  1997
# 1  Grave of the Fireflies   Isao Takahata                 True  1988
# 2             Porco Rosso  Hayao Miyazaki                False  1992
# 3     Tales from Earthsea   Gorō Miyazaki                False  2006
# 4           Spirited Away  Hayao Miyazaki                False  2001
#
#    won oscar
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True

# %% [markdown]
# Per applicare i cambiamenti alla nostra variabile, usiamo il parametro opzionale `inplace`:

# %%
ghibli_movies.sort_values("year", inplace=True)
ghibli_movies
# Out:
#                     title        director  saddest movie ever?  year  \
# 1  Grave of the Fireflies   Isao Takahata                 True  1988
# 2             Porco Rosso  Hayao Miyazaki                False  1992
# 0       Princess Mononoke  Hayao Miyazaki                False  1997
# 4           Spirited Away  Hayao Miyazaki                False  2001
# 3     Tales from Earthsea   Gorō Miyazaki                False  2006
#
#    won oscar
# 1      False
# 2      False
# 0      False
# 4       True
# 3      False

# %%
def optional_arguments(non_optional, optional=False, optional2=0):
    print(f"non optional is {non_optional}")
    print(f"optional is {optional}")
    print(f"optional2 is {optional2}")


optional_arguments(42, optional2=-1)
# Out:
# non optional is 42
# optional is False
# optional2 is -1

# %% [markdown]
# **Oppure** riassegnamo la variabile:

# %%
ghibli_movies = ghibli_movies.sort_values("year")
ghibli_movies
# Out:
#                     title        director  saddest movie ever?  year  \
# 1  Grave of the Fireflies   Isao Takahata                 True  1988
# 2             Porco Rosso  Hayao Miyazaki                False  1992
# 0       Princess Mononoke  Hayao Miyazaki                False  1997
# 4           Spirited Away  Hayao Miyazaki                False  2001
# 3     Tales from Earthsea   Gorō Miyazaki                False  2006
#
#    won oscar
# 1      False
# 2      False
# 0      False
# 4       True
# 3      False

# %% [markdown]
# A questo punto però abbiamo "incasinato" gli indici del nostro DataFrame. Per evitare questa situazione, possiamo usare `ignore_index` quando facciamo `sort`:

# %%
ghibli_movies = ghibli_movies.sort_values("year", ignore_index=True)
ghibli_movies
# Out:
#                     title        director  saddest movie ever?  year  \
# 0  Grave of the Fireflies   Isao Takahata                 True  1988
# 1             Porco Rosso  Hayao Miyazaki                False  1992
# 2       Princess Mononoke  Hayao Miyazaki                False  1997
# 3           Spirited Away  Hayao Miyazaki                False  2001
# 4     Tales from Earthsea   Gorō Miyazaki                False  2006
#
#    won oscar
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False

# %%
ghibli_movies_titles = ghibli_movies["title"]
ghibli_movies_sorted = ghibli_movies.sort_values("year", ignore_index=True)
ghibli_movies_sorted["title"] = ghibli_movies_titles
ghibli_movies_sorted
# Out:
#                     title        director  saddest movie ever?  year  \
# 0       Princess Mononoke   Isao Takahata                 True  1988
# 1  Grave of the Fireflies  Hayao Miyazaki                False  1992
# 2             Porco Rosso  Hayao Miyazaki                False  1997
# 3     Tales from Earthsea  Hayao Miyazaki                False  2001
# 4           Spirited Away   Gorō Miyazaki                False  2006
#
#    won oscar
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False

# %% [markdown]
# ## Una breve nota su `index`
#
# Quando salviamo file usando Pandas, la libreria inserisce anche gli indici come colonna. Vediamo subito il risultato in un file CSV:

# %%
ghibli_movies.to_csv("output/ghibli.csv")

# %% [markdown]
# Se non vogliamo includere gli indici, possiamo usare il parametro opzionale `index`:

# %%
ghibli_movies.to_csv("output/ghibli.csv", index=False)

# %%
ghibli_movies = pd.read_csv("output/ghibli.csv")
ghibli_movies
# Out:
#                     title        director  saddest movie ever?  year  \
# 0  Grave of the Fireflies   Isao Takahata                 True  1988
# 1             Porco Rosso  Hayao Miyazaki                False  1992
# 2       Princess Mononoke  Hayao Miyazaki                False  1997
# 3           Spirited Away  Hayao Miyazaki                False  2001
# 4     Tales from Earthsea   Gorō Miyazaki                False  2006
#
#    won oscar
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False

# %% [markdown]
# ## Quiz
#
# 1. Una persona malvagia ha messo in disordine il file che contiene tutte le informazioni sugli Oscar! Aprilo (in `data/academyawards_mess.csv`) usando Pandas e riordina le righe usando `award_year`. Salva il file in formato CSV in `outputs/academyawards_fixed.csv` non inserendo gli indici.

# %%
academyawards = pd.read_csv("data/academyawards_mess.csv")
academyawards.sort_values("award_year", inplace=True)
academyawards.to_csv("output/academyawards_fixed.csv", index=False)
academyawards.head()
# Out:
#                              movie       imdb  year  award_year  \
# 36                           Wings  tt0018578  1927        1929
# 3              The Broadway Melody  tt0019729  1929        1930
# 55  All Quiet on the Western Front  tt0020629  1930        1930
# 46                        Cimarron  tt0021746  1931        1931
# 0                      Grand Hotel  tt0022958  1932        1932
#
#                                        directors            companies  \
# 36  William A. Wellman, Harry d’Abbadie d’Arrast   Paramount Pictures
# 3                                 Harry Beaumont  Metro-Goldwyn-Mayer
# 55                    Lewis Milestone, Nate Watt   Universal Pictures
# 46                                Wesley Ruggles         RKO Pictures
# 0                                Edmund Goulding  Metro-Goldwyn-Mayer
#
#     male_cast  female_cast
# 36         12            5
# 3           4            3
# 55         22            6
# 46         13            6
# 0          19            8

# %% [markdown]
# # Liste dentro alle celle
#
# Oltre a strutture puramente bidimensionali, Pandas ci consente anche di creare strutture più complesse (annidate). Ce ne sarebbero molti tipi, ma noi vediamo solo una versione, quella in cui creiamo una lista all'interno di una cella del DataFrame. Per farlo, usiamo il metodo "split" su stringhe, che divide una stringa usando un separatore

# %%
academyawards = pd.read_csv("data/academyawards.csv")

academyawards["directors"] = academyawards["directors"].str.split(",")
academyawards
# Out:
#                              movie       imdb  year  award_year  \
# 0                            Wings  tt0018578  1927        1929
# 1              The Broadway Melody  tt0019729  1929        1930
# 2   All Quiet on the Western Front  tt0020629  1930        1930
# 3                         Cimarron  tt0021746  1931        1931
# 4                      Grand Hotel  tt0022958  1932        1932
# ..                             ...        ...   ...         ...
# 80                       Spotlight  tt1895587  2015        2016
# 81                       Moonlight  tt4975722  2016        2017
# 82              The Shape of Water  tt5580390  2017        2018
# 83                      Green Book  tt6966692  2018        2019
# 84                        Parasite  tt6751668  2019        2020
#
#                                           directors  \
# 0   [William A. Wellman,  Harry d’Abbadie d’Arrast]
# 1                                  [Harry Beaumont]
# 2                     [Lewis Milestone,  Nate Watt]
# 3                                  [Wesley Ruggles]
# 4                                 [Edmund Goulding]
# ..                                              ...
# 80                                   [Tom McCarthy]
# 81                                  [Barry Jenkins]
# 82                             [Guillermo del Toro]
# 83                                 [Peter Farrelly]
# 84                                   [Bong Joon-ho]
#
#                                             companies  male_cast  female_cast
# 0                                  Paramount Pictures         12            5
# 1                                 Metro-Goldwyn-Mayer          4            3
# 2                                  Universal Pictures         22            6
# 3                                        RKO Pictures         13            6
# 4                                 Metro-Goldwyn-Mayer         19            8
# ..                                                ...        ...          ...
# 80                     Anonymous Content, Participant         15            2
# 81                          Plan B Entertainment, A24          6            2
# 82            Searchlight Pictures, TSG Entertainment          8            3
# 83  Universal Pictures, DreamWorks, Participant, A...          7            1
# 84                     CJ Entertainment, Barunson E&A          5            5
#
# [85 rows x 8 columns]

# %% [markdown]
# Per accedere all'ennesimo elemento di queste liste scriviamo:

# %%
academyawards.loc[0,"directors"][0]
# Out:
# 'William A. Wellman'

# %% [markdown]
# Possiamo assegnare una lista a una cella usando `.at`, `.loc` non funziona!

# %%
# this does not work
academyawards.loc[0,"directors"] = ["Some", "Directors"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 # this does not work
# ----> 2 academyawards.loc[0,"directors"] = ["Some", "Directors"]
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:1953, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1950 # align and set the values
#    1951 if take_split_path:
#    1952     # We have to operate column-wise
# -> 1953     self._setitem_with_indexer_split_path(indexer, value, name)
#    1954 else:
#    1955     self._setitem_single_block(indexer, value, name)
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:2009, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    2004     if len(value) == 1 and not is_integer(info_axis):
#    2005         # This is a case like df.iloc[:3, [1]] = [0]
#    2006         #  where we treat as df.iloc[:3, 1] = 0
#    2007         return self._setitem_with_indexer((pi, info_axis[0]), value[0])
# -> 2009     raise ValueError(
#    2010         "Must have equal len keys and value when setting with an iterable"
#    2011     )
#    2013 elif lplane_indexer == 0 and len(value) == len(self.obj.index):
#    2014     # We get here in one case via .loc with an all-False mask
#    2015     pass
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
academyawards.at[0,"directors"] = ["Some", "Directors"]
academyawards.head()
# Out:
#                             movie       imdb  year  award_year  \
# 0                           Wings  tt0018578  1927        1929
# 1             The Broadway Melody  tt0019729  1929        1930
# 2  All Quiet on the Western Front  tt0020629  1930        1930
# 3                        Cimarron  tt0021746  1931        1931
# 4                     Grand Hotel  tt0022958  1932        1932
#
#                        directors            companies  male_cast  female_cast
# 0              [Some, Directors]   Paramount Pictures         12            5
# 1               [Harry Beaumont]  Metro-Goldwyn-Mayer          4            3
# 2  [Lewis Milestone,  Nate Watt]   Universal Pictures         22            6
# 3               [Wesley Ruggles]         RKO Pictures         13            6
# 4              [Edmund Goulding]  Metro-Goldwyn-Mayer         19            8

# %% [markdown]
# # groupby
#
# Un altro metodo utile di Pandas è groupby. Questo metodo ci consente di "raggruppare" il DataFrame usando i valori di una colonna specifica. Vediamo un esempio:

# %%
animals = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})
animals.groupby("Animal")

# %% [markdown]
# `groupby` ha ora raggruppato le righe tramite i valori della colonna `Animal`. Tuttavia, non possiamo ancora usare questo risultato. Dobbiamo invece usare un metodo per dire a Pandas come aggregare i valori (in questo caso le velocità medie)

# %%
animals.groupby("Animal").mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %% [markdown]
# Possiamo anche contare quante volte appare ciascun animale!

# %%
animals.groupby("Animal").count()
# Out:
#         Max Speed
# Animal
# Falcon          2
# Parrot          2

# %% [markdown]
# Cosa succede se abbiamo anche colonne con valori non numerici?

# %%
meteo_bolo = pd.read_csv("data/meteo_bologna.csv")
meteo_bolo
# Out:
#             Data  Temperatura media  Temperatura massima  Temperatura minima  \
# 0     2001-01-05                3.7                  6.3                 1.4
# 1     2001-01-08                7.1                  9.5                 3.9
# 2     2001-01-09                8.9                 14.0                 5.6
# 3     2001-01-10                8.1                 12.5                 5.2
# 4     2001-01-17                0.1                  1.8                -1.3
# ...          ...                ...                  ...                 ...
# 8850  2003-09-16               18.7                 26.0                12.6
# 8851  2003-09-17               19.8                 27.4                13.7
# 8852  2003-09-21               22.4                 30.2                16.3
# 8853  2003-09-22               22.7                 29.8                15.7
# 8854  2003-09-26               15.4                 22.1                10.4
#
#      Stagione  Precipitazioni (mm)
# 0     Inverno                  0.1
# 1     Inverno                  6.2
# 2     Inverno                  0.3
# 3     Inverno                  0.1
# 4     Inverno                  1.2
# ...       ...                  ...
# 8850   Estate                  0.0
# 8851   Estate                  0.0
# 8852   Estate                  0.0
# 8853   Estate                  0.0
# 8854  Autunno                  0.0
#
# [8855 rows x 6 columns]

# %%
# it doesn't work! the column data contains strings, 
# it does not support mean
meteo_bolo.groupby("Stagione").mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 # it doesn't work! the column data contains strings,
#       2 # it does not support mean
# ----> 3 meteo_bolo.groupby("Stagione").mean()
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/internals/managers.py:1646, in BlockManager.grouped_reduce(self, func)
#    1644             result_blocks = extend_blocks(applied, result_blocks)
#    1645     else:
# -> 1646         applied = blk.apply(func)
#    1647         result_blocks = extend_blocks(applied, result_blocks)
#    1649 if len(result_blocks) == 0:
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/internals/blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/groupby/ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/groupby/ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/arrays/base.py:2807, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2793 if isinstance(self.dtype, StringDtype):
#    2794     # StringArray
#    2795     if op.how in [
#    2796         "prod",
#    2797         "mean",
#    (...)   2805         "kurt",
#    2806     ]:
# -> 2807         raise TypeError(
#    2808             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2809         )
#    2810     if op.how not in ["any", "all"]:
#    2811         # Fail early to avoid conversion to object
#    2812         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'

# %% [markdown]
# Dobbiamo filtrare e usare solo le colonne che ci servono!

# %%
meteo_bolo_stagioni = meteo_bolo[["Stagione", "Precipitazioni (mm)",
                                  "Temperatura media"]]
meteo_bolo_stagioni.groupby("Stagione").mean()
# Out:
#            Precipitazioni (mm)  Temperatura media
# Stagione
# Autunno               2.596114          11.373221
# Estate                1.472473          24.527704
# Inverno               1.902717           5.884944
# Primavera             2.412218          17.085347

# %% [markdown]
# ## concat

# %% [markdown]
# Oltre alla possibilità di aggiungere righe e colonne, Pandas offre una serie di metodi per combinare più DataFrame in uno. Il primo è `concat`, che concatena le righe di un DataFrame ad un altro.

# %%
ghibli_1 = pd.DataFrame({
    "title": ["Princess Mononoke", "Grave of the Fireflies"],
    "director" : ["Hayao Miyazaki", "Isao Takahata"],
    "year": [1997, 1988]
})

ghibli_2 = pd.DataFrame({
    "title": ["Porco Rosso", "Tales from Earthsea"],
    "director": ["Hayao Miyazaki", "Gorō Miyazaki"],
    "year": [1992, 2006]
})

ghibli_movies = pd.concat((ghibli_1, ghibli_2))
ghibli_movies
# Out:
#                     title        director  year
# 0       Princess Mononoke  Hayao Miyazaki  1997
# 1  Grave of the Fireflies   Isao Takahata  1988
# 0             Porco Rosso  Hayao Miyazaki  1992
# 1     Tales from Earthsea   Gorō Miyazaki  2006

# %%
ghibli_movies.loc[0]
# Out:
#                title        director  year
# 0  Princess Mononoke  Hayao Miyazaki  1997
# 0        Porco Rosso  Hayao Miyazaki  1992

# %% [markdown]
# Se vogliamo risistemare gli indici usiamo `ignore_index`:

# %%
ghibli_movies = pd.concat((ghibli_1, ghibli_2), ignore_index=True)
ghibli_movies
# Out:
#                     title        director  year
# 0       Princess Mononoke  Hayao Miyazaki  1997
# 1  Grave of the Fireflies   Isao Takahata  1988
# 2             Porco Rosso  Hayao Miyazaki  1992
# 3     Tales from Earthsea   Gorō Miyazaki  2006

# %% [markdown]
# Cosa succede se abbiamo colonne in una tabella ma nell'altra non ci sono?

# %%
ghibli_1["won oscar"]=False
ghibli_1
# Out:
#                     title        director  year  won oscar
# 0       Princess Mononoke  Hayao Miyazaki  1997      False
# 1  Grave of the Fireflies   Isao Takahata  1988      False

# %%
ghibli_movies = pd.concat((ghibli_1, ghibli_2), ignore_index=True)
ghibli_movies
# Out:
#                     title        director  year won oscar
# 0       Princess Mononoke  Hayao Miyazaki  1997     False
# 1  Grave of the Fireflies   Isao Takahata  1988     False
# 2             Porco Rosso  Hayao Miyazaki  1992       NaN
# 3     Tales from Earthsea   Gorō Miyazaki  2006       NaN

# %%
ghibli_1["bello"] = "bello"
pd.concat((ghibli_1, ghibli_2), ignore_index=True)
# Out:
#                     title        director  year won oscar  bello
# 0       Princess Mononoke  Hayao Miyazaki  1997     False  bello
# 1  Grave of the Fireflies   Isao Takahata  1988     False  bello
# 2             Porco Rosso  Hayao Miyazaki  1992       NaN    NaN
# 3     Tales from Earthsea   Gorō Miyazaki  2006       NaN    NaN

# %% [markdown]
# ## join
#
#
# Un'altra posssibilità è quella di voler unire le colonne di due DataFrame. Lo si fa con `join`

# %%
names = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda"], 
                      "surnames": ["Esposito", "Testa", "Barbieri", "Gallo"]})
ages = pd.DataFrame({"ages": [64, 30, 43, 88]})

names.join(ages)
# Out:
#      names  surnames  ages
# 0   Andrea  Esposito    64
# 1  Claudia     Testa    30
# 2    Piero  Barbieri    43
# 3  Mafalda     Gallo    88

# %% [markdown]
# Cosa succede se la stessa colonna appare più volte?

# %%
names = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda"],
                      "surnames": ["Esposito", "Testa", "Barbieri", "Gallo"]})
ages = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda"], 
                     "ages": [64, 30, 43, 88]})
names.join(ages)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 5
#       1 names = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda"],
#       2                       "surnames": ["Esposito", "Testa", "Barbieri", "Gallo"]})
#       3 ages = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda"],
#       4                      "ages": [64, 30, 43, 88]})
# ----> 5 names.join(ages)
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/frame.py:12804, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   12800                     suffixes=(lsuffix, rsuffix),
#   12801                     sort=sort,
#   12802                     validate=validate,
#   12803                 )
# > 12804             return merge(
#   12805                 self,
#   12806                 other,
#   12807                 left_on=on,
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:399, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     384 else:
#     385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#    (...)    397         validate=validate,
#     398     )
# --> 399     return op.get_result()
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:1143, in _MergeOperation.get_result(self)
#    1139     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#    1141 join_index, left_indexer, right_indexer = self._get_join_info()
# -> 1143 result = self._reindex_and_concat(join_index, left_indexer, right_indexer)
#    1145 if self.indicator:
#    1146     result = self._indicator_post_merge(result)
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:1094, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer)
#    1091 left = self.left[:]
#    1092 right = self.right[:]
# -> 1094 llabels, rlabels = _items_overlap_with_suffix(
#    1095     self.left._info_axis, self.right._info_axis, self.suffixes
#    1096 )
#    1098 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#    1099     # Pinning the index here (and in the right code just below) is not
#    1100     #  necessary, but makes the `.take` more performant if we have e.g.
#    1101     #  a MultiIndex for left.index.
#    1102     lmgr = left._mgr.reindex_indexer(
#    1103         join_index,
#    1104         left_indexer,
#    (...)   1108         use_na_proxy=True,
#    1109     )
#
# File ~/Lavoro/didattica/.venv/lib/python3.14/site-packages/pandas/core/reshape/merge.py:3092, in _items_overlap_with_suffix(left, right, suffixes)
#    3089 lsuffix, rsuffix = suffixes
#    3091 if not lsuffix and not rsuffix:
# -> 3092     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    3094 def renamer(x, suffix: str | None):
#    3095     """
#    3096     Rename the left and right indices.
#    3097
#    (...)   3108     x : renamed column name
#    3109     """
#
# ValueError: columns overlap but no suffix specified: Index(['names'], dtype='str')

# %% [markdown]
# Non possiamo farlo! Le colonne avrebbero lo stesso nome! Se vogliamo fare `join` dobbiamo specificare un suffisso per una o entrambe le colonne

# %%
names = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda"], 
                      "surnames": ["Esposito", "Testa", "Barbieri", "Gallo"]})
ages = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda"], 
                     "ages": [64, 30, 43, 88]})
names.join(ages, lsuffix="-left", rsuffix="-right")
# Out:
#   names-left  surnames names-right  ages
# 0     Andrea  Esposito      Andrea    64
# 1    Claudia     Testa     Claudia    30
# 2      Piero  Barbieri       Piero    43
# 3    Mafalda     Gallo     Mafalda    88

# %% [markdown]
# ## merge
#
# Infine, possiamo "unire" due DataFrame. In questo caso, il sistema controllerà dove le colonne che sono presenti in entrambi i DataFrame hanno lo stesso valore, unendo le que righe corrispondenti:

# %%
names = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda"], 
                      "surnames": ["Esposito", "Testa", "Barbieri", "Gallo"]})
ages = pd.DataFrame({"names": ["Claudia", "Piero", "Mafalda", "Andrea"], 
                     "ages": [64, 30, 43, 88]})
pd.merge(names, ages)
# Out:
#      names  surnames  ages
# 0  Claudia     Testa    64
# 1    Piero  Barbieri    30
# 2  Mafalda     Gallo    43

# %%
# what happens when there are rows on one side and not the other?
names = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", 
                                "Mafalda", "Giovanni"], 
                      "surnames": ["Esposito", "Testa", "Barbieri", 
                                   "Gallo", "Serra"]})
ages = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", 
                               "Mafalda", "Antonio"], 
                     "ages": [64, 30, 43, 88, 24]})
pd.merge(names, ages)
# Out:
#      names  surnames  ages
# 0   Andrea  Esposito    64
# 1  Claudia     Testa    30
# 2    Piero  Barbieri    43
# 3  Mafalda     Gallo    88

# %%
# or i could do an outer merge
names = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda", "Giovanni"], 
                      "surnames": ["Esposito", "Testa", "Barbieri", "Gallo", "Serra"]})
ages = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda", "Antonio"], 
                     "ages": [64, 30, 43, 88, 24]})
                     
pd.merge(names, ages, how="outer")
# Out:
#       names  surnames  ages
# 0    Andrea  Esposito  64.0
# 1   Antonio       NaN  24.0
# 2   Claudia     Testa  30.0
# 3  Giovanni     Serra   NaN
# 4   Mafalda     Gallo  88.0
# 5     Piero  Barbieri  43.0

# %%
# or i could do an outer merge
names = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda", "Giovanni"], 
                      "surnames": ["Esposito", "Testa", "Barbieri", "Gallo", "Serra"]})
ages = pd.DataFrame({"names": ["Andrea", "Claudia", "Piero", "Mafalda", "Antonio"], 
                     "ages": [64, 30, 43, 88, 24]})
                     
pd.merge(names, ages, how="right")
# Out:
#      names  surnames  ages
# 0   Andrea  Esposito    64
# 1  Claudia     Testa    30
# 2    Piero  Barbieri    43
# 3  Mafalda     Gallo    88
# 4  Antonio       NaN    24

# %% [markdown]
# ## Quiz
#
# 1. Scarica i dati di temperatura e precipitazioni (disaggregati) da [qui](https://opendata.comune.bologna.it/explore/?sort=modified&refine.theme=Ambiente). Unisci i due file CSV usando Pandas.

# %%
# CAUTION: use semicolon (;) as separator
temperature = pd.read_csv("data/temperature_bologna.csv", sep=";")
precipitazioni = pd.read_csv("data/precipitazioni_bologna.csv", sep=";")

pd.merge(temperature, precipitazioni)
# Out:
#             Data  Temperatura media  Temperatura massima  Temperatura minima  \
# 0     2003-10-03               21.5                 28.2                16.2
# 1     2003-10-04               21.6                 27.2                15.9
# 2     2003-10-09               17.1                 24.1                10.8
# 3     2003-10-10               16.8                 24.3                11.2
# 4     2003-10-11               18.6                 24.5                12.9
# ...          ...                ...                  ...                 ...
# 9242  2026-04-05               15.5                 23.0                 8.1
# 9243  2026-04-08               16.5                 23.0                10.7
# 9244  2026-04-12               13.8                 15.8                10.2
# 9245  2026-04-17               17.8                 24.3                12.0
# 9246  2026-04-18               18.5                 24.8                12.2
#
#        Stagione  Precipitazioni (mm)
# 0       Autunno                  0.0
# 1       Autunno                  1.9
# 2       Autunno                  0.0
# 3       Autunno                  0.0
# 4       Autunno                  0.0
# ...         ...                  ...
# 9242  Primavera                  0.0
# 9243  Primavera                  0.0
# 9244  Primavera                  0.6
# 9245  Primavera                  0.0
# 9246  Primavera                  0.0
#
# [9247 rows x 6 columns]
